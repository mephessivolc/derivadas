# %%
from sympy import symbols

from sympy.plotting import plot

# %%
x,y,z = symbols('x,y,z')

# %%
init_printing(use_unicode=True)

# %%
cos = diff(sin(x), x)

# %%
diff(x**2+3*x+2, x)
# Out:
# 2⋅x + 3

# %%
expr = diff(diff(x**3+3*x**2+2*x+3, x), x)
print("{} {}".format(expr, "teste"))
# Out:
# 6*x + 6 teste

# %%
p1 = plot(expr) # constroi grafico
p2 = plot(cos) # constroi grafico
p3 = plot(x**x)
p1.append((p2[0], p3[0])) # adiciona o segundo grafico no primeiro

p1.save("teste.png") # para salvar a imagem do grafico na pasta origem
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5a1e9cd34300> in <module>
#       2 p2 = plot(cos) # constroi grafico
#       3 p3 = plot(x**x)
# ----> 4 p1.append((p2[0], p3[0])) # adiciona o segundo grafico no primeiro
#       5
#       6 p1.save("teste.png") # para salvar a imagem do grafico na pasta origem
#
# ~/Documentos/python/simpy/devSimpy/lib/python3.6/site-packages/sympy/plotting/plot.py in append(self, arg)
#     247             self._series.append(arg)
#     248         else:
# --> 249             raise TypeError('Must specify element of plot to append.')
#     250
#     251     def extend(self, arg):
#
# TypeError: Must specify element of plot to append.
